# %% [markdown]
# # Transformer Architecture
#
# In this section we are going to go through all the inidivudal components of this neural network that compose a transformer, having a great inspiration from the GPT-2 open source model to guide our design decisions, now following up we will visit each of the founding blocks of this marvel:
#
# ![image.png](data:image/png;base64,...)

# %%
import torch
from torch import nn
import pandas as pd
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
